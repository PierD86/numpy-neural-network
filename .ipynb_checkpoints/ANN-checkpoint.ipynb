# %% [markdown]
# # What is an Artificial Neural Network (ANN)?
# *reference idea https://www.seas.upenn.edu/~cis519/fall2017/lectures/11_NeuralNets.pdf*<br>
# <br>
# ![image.png](attachment:eb576e49-8b7e-4b6d-a547-ff89f539b8e6.png)!<br>
# *image from https://towardsdatascience.com/a-neural-network-from-scratch-c09fd2dea45d*

# %% [markdown]
# ### Architecture:
# > - 2 input nodes (number of features of the model)
# > - 2 hidden layers with 3 nodes each (level of complexity of the model)
# > - 1 output node (number of target variables of the model)

# %% [markdown]
# *Each node can be seen like this:*<br>
# ![image.png](attachment:2ffc1e5d-cda6-4af3-a00b-57cd041be139.png)!<br>
# *image from https://towardsdatascience.com/a-neural-network-from-scratch-c09fd2dea45d*<br>
# where:<br>
# > - $X$ is the vector of examples
# > - $W$ is the vector of weights
# > - $b$ is the bias
# > - $g(z)$ is the activation function, usually we use:
# >> - the relu function $relu(z)$ for hidden layers
# >> - the sigmoid function $\sigma(z)$ for output layer

# %% [markdown]
# *ANN can be seen like this:* <br>
# ![image.png](attachment:6969ef4a-6b43-4fad-a541-299da4e7c7ea.png)!<br>
# *image from https://towardsdatascience.com/a-neural-network-from-scratch-c09fd2dea45d*

# %% [markdown]
# ### How an ANN is trained?
# ![image.png](attachment:ad59431b-61b4-4410-b3d3-5e747097c3c5.png)! <br>
# *image from https://towardsdatascience.com/a-neural-network-from-scratch-c09fd2dea45d*<br>
# > - **Initialization:** all weights $W$ and biases b are initialized at random
# > - **Forward Propagation:** the example $x_i$ (or a batch of examples) are propagated trought the output
# > - **Cost calculation:** Cost function $J$ is calculated (some error function)
# > - **Backward Propagation:** Cost $J$ is derived with respect to all weights and biases to find the relative corrections *(gradient descent)*

# %% [markdown]
# #### Some Math
# > - *sigmoid function*<br>
# \begin{equation}
# \sigma(z) = \frac{\mathrm{1} }{\mathrm{1} + e^{-z} }
# \end{equation}
# <br>
# > - *ReLu function*<br>
# \begin{equation}
# R(z) = max(0,z)
# \end{equation}
# <br>
#
# ![image.png](attachment:9e9690d7-da78-441c-b5bb-95d639c794f2.png)!<br>
# *image from* https://towardsdatascience.com/activation-functions-neural-networks-1cbd9f8d91d6 <br>
#
# > - *cost function*, binary cross entropy<br>
# \begin{equation}
# J(x_i) = -\frac{1}{m}\sum_{i=1}^{m}(y_i \log(\hat{y}_i) + (1-y_i)\log(1-\hat{y}_i))\\
# m = \text{number of training examples}
# \end{equation}
#
#
# #### Notations (for the Back Propagation phase)
# > - *weights and bias correction* for layer **L**<br>
# \begin{equation}
# \partial W^{L} = \frac{\partial J}{\partial W^L}\\
# \partial b^{L} = \frac{\partial J}{\partial b^L}
# \end{equation}<br>

# %% [markdown]
# ## Dimensions
# *matrices dimensions to better understand following formulas*
# > - #### Note
# >> - $A^o = \hat{Y}$
# >> - $m$ = number of training examples
# >> - $n_x$ = number of features (inputs)
# >> - $n_1$ = number of nodes in the $1_{st}$ hidden layer
# >> - $n_2$ = number of nodes in the $2_{nd}$ hidden layer
# >> - $n_o$ = number of target variables (outputs)
#
# > - #### Weights, biases, inputs and outputs
# >> *first layer*
# >> - $X = n_x \times m$
# >> - $W^1 = n_1 \times n_x$
# >> - $b^1 = n_1 \times m$
# >> - $Z^1 = n_1 \times m$
# >> - $A^1 = n_1 \times m$
# >> *second layer*
# >> - $W^2 = n_2 \times n_1$
# >> - $b^2 = n_2 \times m$
# >> - $Z^2 = n_2 \times m$
# >> - $A^2 = n_2 \times m$
# >> *output layer*
# >> - $W^o = n_o \times n_1$
# >> - $b^o = n_o \times m$
# >> - $Z^o = n_o \times m$
# >> - $A^o = n_o \times m$

# %% [markdown]
# ## Formulas
# *example for 2 hidden layers and 1 output layer*
#
# > - #### Initialization
# >> *first layer*
# >> - $W^1 = \sim \mathcal{N}(0,1)$
# >> - $b^1 = 0$
# >> *second layer*
# >> - $W^2 = \sim \mathcal{N}(0,1)$
# >> - $b^2 = 0$
# >> *output layer*
# >> - $W^o = \sim \mathcal{N}(0,1)$
# >> - $b^o = 0$
#
# > - #### Forward Propagation
# >> *first layer*
# >> - $Z^1 = W^1 X + b^1$ -- first layer nodes
# >> - $A^1 = R(Z^1)$ -- first layer activation functions
# >> *second layer*
# >> - $Z^2 = W^2 A^1 + b^2$ -- second layer nodes
# >> - $A^2 = R(Z^2)$ -- second layer activation functions
# >> *output layer*
# >> - $Z^o = W^o A^2 + b^o$ -- output layer nodes
# >> - $A^o = \sigma(Z^o)$ -- output layer activation functions
#
# > - #### Back Propagation
#
# >> *output layer*
# >> - $\partial Z^o = A^o - Y$
# >> - $\partial W^o = \frac{1}{m} \cdot \partial Z^o \cdot A'^{2}$
# >> - $\partial b^o = \frac{1}{m} \cdot \sum_{i=1}^{n}\partial Z_i^o$
# >> *second layer*
# >> - $\partial Z^2 = W'^o \cdot \partial Z^o * \mathcal{D}[\sigma(Z^o)]$
# >> - $\partial W^2 = \frac{1}{m} \cdot \partial Z^2 \cdot A'^{1}$
# >> - $\partial b^2 = \frac{1}{m} \cdot \sum_{i=1}^{n}\partial Z_i^2$
# >> *first layer*
# >> - $\partial Z^1 = W'^o \cdot \partial Z^o * \mathcal{D}[\sigma(Z^1)]$
# >> - $\partial W^1 = \frac{1}{m} \cdot \partial Z^1 \cdot X'$
# >> - $\partial b^1 = \frac{1}{m} \cdot \sum_{i=1}^{n}\partial Z_i^1$

# %% [markdown]
# #### Gradient Descent
# *reference idea* http://rasbt.github.io/mlxtend/user_guide/general_concepts/gradient-optimization/<br>
# ![image.png](attachment:97d76895-f3ea-44e9-9cc9-5548ad79a062.png)<br>
# *image from* http://rasbt.github.io/mlxtend/user_guide/general_concepts/gradient-optimization/ <br>
#
# #### Weights and bias update Formulas
# > - #### Note
# >> - these updates are done for every learning epoch
# >> - $\alpha$ is the learning rate
# >> *first layer*
# >> - $W^1 = W^1 - \alpha \cdot \partial W^1$
# >> - $b^1 = b^1 - \alpha \cdot \partial b^1$
# >> *second layer*
# >> - $W^2 = W^2 - \alpha \cdot \partial W^2$
# >> - $b^2 = b^2 - \alpha \cdot \partial b^2$
# >> *output layer*
# >> - $W^o = W^o - \alpha \cdot \partial W^o$
# >> - $b^o = b^o - \alpha \cdot \partial b^o$

# %% [markdown]
# #### Let's cut the chatter (BANDO ALLE CIANCE!!!)

# %%
#libraries
import numpy as np
from sklearn.datasets import make_blobs, make_moons
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import time
SEED = 1926
np.random.seed(SEED)

# %% [markdown]
# #### design of experiments
# the NN architecture will be kept with 2 inputs, 2 hidden layers and 1 binary output
# > - dataset *blobs* with 3 and 2 hidden layer nodes
# > - dataset *moons* with 3 and 2 hidden layer nodes
# > - dataset *moons* with 10 and 10 hidden layer nodes

# %%
DATASET_TYPE = 'blobs'

# %%
#create a classification dataset
if DATASET_TYPE == 'blobs': 
    X, Y = make_blobs(n_samples=1000, n_features=2, centers=2, random_state=SEED)
if DATASET_TYPE == 'moons':
    X, Y = make_moons(n_samples=1000, noise=0.2, random_state=SEED)
df = pd.DataFrame()
df['x1'], df['x2'], df['Y'] = X[:,0], X[:,1], Y
plt.subplots()
sns.scatterplot(data=df, x='x1',y='x2', hue='Y');
plt.suptitle('real classes');

# %%
#matrices shapes
m = X.shape[0] #number of examples
nx = X.shape[1] #number of features
n1 = 3 #hidden layer 1 nodes
n2 = 2 #hidden layer 2 nodes
no = 1 #output layer nodes

# %%
#initialization
alpha = 0.1
epochs = 2000
W1 = np.random.randn(n1,nx)
b1 = np.zeros((n1,m))
W2 = np.random.randn(n2,n1)
b2 = np.zeros((n2,m))
Wo = np.random.randn(no,n2)
bo = np.zeros((no,m))

# %%
#save initial weights for later
W10, W20, Wo0 = W1, W2, Wo
b10, b20, bo0 = b1[:,0], b2[:,0], bo[:,0]

# %%
def relu(x):
    return np.maximum(0,x)

def relu_derivative(x):
    return np.greater(x, 0).astype(int)

def sigmoid(x):
    return 1/(1+np.exp(-x))

def sigmoid_derivative(x):
    return sigmoid(x)*(1-sigmoid(x))

# %%
#forward propagation
def execute_forward_propagation(W1, b1, W2, b2, Wo, bo):
    Z1 = np.dot(W1,X.T) + b1
    A1 = relu(Z1)

    Z2 = np.dot(W2,A1) + b2
    A2 = relu(Z2)

    Zo = np.dot(Wo,A2) + bo
    Ao = sigmoid(Zo)
    return A1, Z1, A2, Z2, Ao, Zo

# %%
#back propagation
def execute_back_propagation(A1, Z1, A2, Z2, Ao, Zo, Y):
    dZo = Ao - Y.reshape(-1,1).T
    dWo = 1/m * np.dot(dZo,A2.T)
    dbo = 1/m * np.sum(dZo, axis=1, keepdims=True)
    dA2 = np.dot(Wo.T,dZo)

    dZ2 = dA2 * relu_derivative(Z2)
    dW2 = 1/m * np.dot(dZ2,A1.T)
    db2 = 1/m * np.sum(dZ2, axis=1, keepdims=True)
    dA1 = np.dot(W2.T,dZ2)

    dZ1 = dA1 * relu_derivative(Z1)
    dW1 = 1/m * np.dot(dZ1,X)
    db1 = 1/m * np.sum(dZ1, axis=1, keepdims=True)
    return dW1, db1, dW2, db2, dWo, dbo

# %%
#Weights and bias update
def update_weights_and_biases(W1, dW1, b1, db1, W2, dW2, b2, db2, Wo, dWo, bo, dbo):
    W1 = W1 - alpha * dW1
    b1 = b1 - alpha * db1

    W2 = W2 - alpha * dW2
    b2 = b2 - alpha * db2

    Wo = Wo - alpha * dWo
    bo = bo - alpha * dbo
    return W1, b1, W2, b2, Wo, bo

# %%
def calculate_loss(Y,Ao):
    Y =Y.reshape(-1,1).T
    Yhat = Ao
    #eps=1e-15
    #loss = Y*np.log(Yhat+eps) + (1-Y)*np.log(1-Yhat+eps)
    loss = Y*np.log(Yhat) + (1-Y)*np.log(1-Yhat)
    J = -(Y*np.log(Yhat) + (1-Y) * np.log(1-Yhat)).mean()
    return J

# %%
#training procedure
start_time = time.time()
J = []
for epoch in range(epochs):
    A1, Z1, A2, Z2, Ao, Zo = execute_forward_propagation(W1, b1, W2, b2, Wo, bo)
    J.append(calculate_loss(Y,Ao))
    dW1, db1, dW2, db2, dWo, dbo = execute_back_propagation(A1, Z1, A2, Z2, Ao, Zo, Y)
    W1, b1, W2, b2, Wo, bo = update_weights_and_biases(W1, dW1, b1, db1, W2, dW2, b2, db2, Wo, dWo, bo, dbo)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.5275905132293701 seconds ---

# %%
#prediction
_, _, _, _, Yhat, _ = execute_forward_propagation(W1, b1, W2, b2, Wo, bo)
Yhat = Yhat.ravel().round()

# %%
#plot of the cost function
ax = plt.plot(J)
plt.xlabel('epochs')
plt.ylabel('cost function J');

# %%
#let's check the accuracy
from sklearn.metrics import accuracy_score
print('final accuracy --> ', accuracy_score(Y,Yhat))
# Out:
# final accuracy -->  1.0

# %%
#plot results
df['Yhat'] = Yhat
fig, ax = plt.subplots(1,2, figsize=(10,5))
sns.scatterplot(data=df, x='x1',y='x2', hue='Y', ax=ax[0])
ax[0].set_title('real classes')
sns.scatterplot(data=df, x='x1',y='x2', hue='Yhat', ax=ax[1]);
ax[1].set_title('predicted classes');

# %% [markdown]
# ### Now let's keep it simple using Keras APIs
# https://keras.io/api/

# %%
#Libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
tf.random.set_seed(SEED)

# %%
SET_WEIGHTS_LIKE_BEFORE = True

# %%
# Neural network
model = Sequential()
model.add(Dense(n1, input_dim=X.shape[1], activation='relu', kernel_initializer='random_normal', bias_initializer='zeros'))
model.add(Dense(n2, activation='relu'))
model.add(Dense(no, activation='sigmoid'))

if SET_WEIGHTS_LIKE_BEFORE:
    model.layers[0].set_weights([W10.T,b10])
    model.layers[1].set_weights([W20.T,b20])
    model.layers[2].set_weights([Wo0.T,bo0])

sgd = keras.optimizers.SGD(learning_rate=alpha)
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])
start_time = time.time()
history = model.fit(X, Y, epochs=epochs, batch_size=X.shape[0], verbose=False)
print("--- %s seconds ---" % (time.time() - start_time))
Yhat_keras = model.predict(X).ravel().round()
# Out:
# --- 4.233696460723877 seconds ---

# %%
#plot of the cost function
ax = plt.plot(history.history['loss'])
plt.xlabel('epochs')
plt.ylabel('keras cost function J');

# %%
#let's check the accuracy
from sklearn.metrics import accuracy_score
print('keras final accuracy --> ', accuracy_score(Y,Yhat_keras))
# Out:
# keras final accuracy -->  1.0

# %%
#plot results
df['Yhat_keras'] = Yhat_keras
fig, ax = plt.subplots(1,3, figsize=(15,5))
sns.scatterplot(data=df, x='x1',y='x2', hue='Y', ax=ax[0])
ax[0].set_title('real classes')
sns.scatterplot(data=df, x='x1',y='x2', hue='Yhat', ax=ax[1]);
ax[1].set_title('predicted classes');
sns.scatterplot(data=df, x='x1',y='x2', hue='Yhat_keras', ax=ax[2]);
ax[2].set_title('predicted classes using keras');
